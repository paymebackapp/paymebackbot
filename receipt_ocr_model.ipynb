# %% [markdown]
# ## OCR Recognition Model for Receipts

# %%
import matplotlib.pyplot as plt
from PIL import Image
import os
# %matplotlib inline


# Load and display a receipt image
fig = plt.figure(figsize=(6, 6))
image_path = os.path.join('sample_images','receipt.jpg')
img = Image.open(image_path)
plt.axis('off')
plt.imshow(img)
